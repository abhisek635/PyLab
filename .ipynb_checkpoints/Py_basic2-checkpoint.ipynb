# %%
pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.3 MB 1.7 MB/s eta 0:00:07
#    --- ------------------------------------ 1.0/12.3 MB 1.8 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.6/12.3 MB 1.8 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.8/12.3 MB 1.9 MB/s eta 0:00:06
#    ------- -------------------------------- 2.4/12.3 MB 2.0 MB/s eta 0:00:06
#    --------- ------------------------------ 2.9/12.3 MB 2.1 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.4/12.3 MB 2.1 MB/s eta 0:00:05
#    ------------- -------------------------- 4.2/12.3 MB 2.2 MB/s eta 0:00:04
#    --------------- ------------------------ 4.7/12.3 MB 2.3 MB/s eta 0:00:04
# ...

# %%
import numpy as noob

# %%
arr1 = noob.array([1, 2, 3])

print(arr1)
# Out:
# [1 2 3]
